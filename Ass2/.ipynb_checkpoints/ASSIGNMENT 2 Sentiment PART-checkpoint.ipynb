# %%
import nltk
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import os
import re

# %%
# Import the LabMT wordlist
df = pd.read_csv("Data_Set_S1.txt", sep="\t") 
# sep='' in the context of a function call sets the named argument sep to an empty string. 
df.head()
# Show the first 5 rows of the dataframe, it looks good
# Out:
#         word  happiness_rank  happiness_average  happiness_standard_deviation  \
# 0   laughter               1               8.50                        0.9313
# 1  happiness               2               8.44                        0.9723
# 2       love               3               8.42                        1.1082
# 3      happy               4               8.30                        0.9949
# 4    laughed               5               8.26                        1.1572
#
#   twitter_rank google_rank nyt_rank lyrics_rank
# 0         3600          --       --        1728
# 1         1853        2458       --        1230
# 2           25         317      328          23
# 3           65        1372     1313         375
# 4         3334        3542       --        2332

# %%
# Get the happiness dictionary
happiness_dict = dict(zip(df['word'],df['happiness_average']))
happiness_dict
# Out:
# {'laughter': 8.5,
#  'happiness': 8.44,
#  'love': 8.42,
#  'happy': 8.3,
#  'laughed': 8.26,
#  'laugh': 8.22,
#  'laughing': 8.2,
#  'excellent': 8.18,
#  'laughs': 8.18,
#  'joy': 8.16,
#  'successful': 8.16,
#  'win': 8.12,
#  'rainbow': 8.1,
#  'smile': 8.1,
#  'won': 8.1,
#  'pleasure': 8.08,
#  'smiled': 8.08,
#  'rainbows': 8.06,
#  'winning': 8.04,
#  'celebration': 8.02,
#  'enjoyed': 8.02,
#  'healthy': 8.02,
#  'music': 8.02,
#  'celebrating': 8.0,
#  'congratulations': 8.0,
#  'weekend': 8.0,
#  'celebrate': 7.98,
#  'comedy': 7.98,
#  'jokes': 7.98,
#  'rich': 7.98,
#  'victory': 7.98,
#  'christmas': 7.96,
#  'free': 7.96,
#  'friendship': 7.96,
#  'fun': 7.96,
#  'holidays': 7.96,
#  'loved': 7.96,
#  'loves': 7.96,
#  'loving': 7.96,
#  'beach': 7.94,
#  'hahaha': 7.94,
#  'kissing': 7.94,
#  'sunshine': 7.94,
#  'beautiful': 7.92,
#  'delicious': 7.92,
#  'friends': 7.92,
#  'funny': 7.92,
#  'outstanding': 7.92,
#  'paradise': 7.92,
#  'sweetest': 7.92,
# ...

# %%
# construct a function to calculate the sentiment value
def calculate_sentiment_value(file):
    with open(file, "r",encoding='UTF-8') as f: 
        a = f.read()
    f.close()
    b = re.split(r'\W+', a)
    c = [word.lower() for word in b if len(word) > 0] 
    
    score = 0
    changdu = len(c)
    for i in c:
        if i in happiness_dict:
            score = score + happiness_dict[i]
        else:
            changdu = changdu - 1
            continue
    if changdu == 0:
        return None
    sentiment_value = score/changdu
    return sentiment_value

# %%
sentiment_value_dc_list = []    # Construct the sentiment-value-list for dc
sentiment_value_dc_list
# Out:
# []

# %%
def findAllFile(base):                           # Design a fucntion to locate all the files in certain folder
    for root, ds, fs in os.walk(base):
        for f in fs:
            if f.endswith('.txt'):
                fullname = os.path.join(root, f)
                yield fullname

def main():
    base = 'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc'
    wenjianjia = []
    for i in findAllFile(base):
        wenjianjia.append(i)
    return wenjianjia


wenjianjia = main()    # Return all the file name

# %%
#calculate_sentiment_value("D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc/711_(Quality_Comics).txt")

# %%
#calculate_sentiment_value(wenjianjia[0])
for i in wenjianjia:
    sentiment_value_dc_list.append(calculate_sentiment_value(i))   # We use the calculate_sentiment_value Function to calculate each value for each txt file.

# %%
sentiment_value_dc_list
# Out:
# [None,
#  5.389032815198586,
#  5.285731064237726,
#  5.40622464126665,
#  5.529271600154953,
#  5.389194229415914,
#  5.4068993993993795,
#  5.470350194552501,
#  5.291917808219179,
#  5.444045290787414,
#  5.571974486966127,
#  5.453398260869513,
#  5.411169590643236,
#  5.406216375997577,
#  5.397945205479454,
#  5.451735947238327,
#  5.54126416739318,
#  5.410853540252163,
#  5.465056472632496,
#  5.512528409090909,
#  5.443552158273357,
#  5.29987508796623,
#  5.575493562231723,
#  5.303140168400142,
#  5.440507246376765,
#  5.464334565619186,
#  5.556300251256249,
#  5.436537879462436,
#  5.43869883934023,
#  5.445366434591424,
#  5.371116751269011,
#  5.415151733064859,
#  5.402253458277507,
#  5.566179326099341,
#  5.433901265371601,
#  5.347444331983758,
#  5.325638207945865,
#  5.401266532167606,
#  5.281621970087624,
#  5.427582733812955,
#  5.389527027026985,
#  5.494579273693522,
#  5.419370021723372,
#  5.4972602739726035,
#  5.29263236088604,
#  5.2946753246753255,
# ...

# %%
def findAllFile2(base):                  # Repeat the procedure
    for root, ds, fs in os.walk(base):
        for f in fs:
            if f.endswith('.txt'):
                fullname = os.path.join(root, f)
                yield fullname

def main():
    base = 'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/marvel'
    wenjianjia2 = []
    for i in findAllFile2(base):
        wenjianjia2.append(i)
    return wenjianjia2


wenjianjia2 = main()

# %%
sentiment_value_marvel_list = []   # As above
sentiment_value_marvel_list
# Out:
# []

# %%
for i in wenjianjia2:
    sentiment_value_marvel_list.append(calculate_sentiment_value(i))

# %%
sentiment_value_marvel_list
# Out:
# [5.488878069432629,
#  5.335026002971731,
#  5.331379210220604,
#  5.383867768594975,
#  5.307005899704988,
#  5.3297792408985005,
#  5.425455588707747,
#  5.397945205479454,
#  5.460832514734795,
#  5.452996655518379,
#  5.529410774410753,
#  5.3618174962292535,
#  5.365564614757397,
#  5.491509635974288,
#  5.482098475967168,
#  5.423991097922853,
#  5.508325545171313,
#  5.436228606356941,
#  5.367058823529414,
#  5.39698795180723,
#  5.449441786283847,
#  5.315432098765433,
#  5.54424988168479,
#  5.29498089171969,
#  5.50313280363223,
#  5.34334415584415,
#  5.308399513776364,
#  5.405606397156782,
#  5.409565217391306,
#  5.407313974591631,
#  5.685624270711784,
#  5.453112840466878,
#  5.397945205479454,
#  5.403826479438266,
#  5.377171000788,
#  5.462296431838954,
#  5.3283582089552235,
#  5.397945205479454,
#  5.453467804499596,
#  5.476338028169017,
#  5.539505928853738,
#  5.2810000000000015,
#  5.417948094079447,
#  5.4037305916911205,
#  5.541724137931053,
# ...

# %%
merge_list = sentiment_value_dc_list + sentiment_value_marvel_list   # Merge the two lists

# %%
merge_list
# Out:
# [None,
#  5.389032815198586,
#  5.285731064237726,
#  5.40622464126665,
#  5.529271600154953,
#  5.389194229415914,
#  5.4068993993993795,
#  5.470350194552501,
#  5.291917808219179,
#  5.444045290787414,
#  5.571974486966127,
#  5.453398260869513,
#  5.411169590643236,
#  5.406216375997577,
#  5.397945205479454,
#  5.451735947238327,
#  5.54126416739318,
#  5.410853540252163,
#  5.465056472632496,
#  5.512528409090909,
#  5.443552158273357,
#  5.29987508796623,
#  5.575493562231723,
#  5.303140168400142,
#  5.440507246376765,
#  5.464334565619186,
#  5.556300251256249,
#  5.436537879462436,
#  5.43869883934023,
#  5.445366434591424,
#  5.371116751269011,
#  5.415151733064859,
#  5.402253458277507,
#  5.566179326099341,
#  5.433901265371601,
#  5.347444331983758,
#  5.325638207945865,
#  5.401266532167606,
#  5.281621970087624,
#  5.427582733812955,
#  5.389527027026985,
#  5.494579273693522,
#  5.419370021723372,
#  5.4972602739726035,
#  5.29263236088604,
#  5.2946753246753255,
# ...

# %%
cleaned_merge_list = []   # Delete the None value

# %%
for i in merge_list:
    if i != None:
        cleaned_merge_list.append(i)

# %%
cleaned_merge_list
# Out:
# [5.389032815198586,
#  5.285731064237726,
#  5.40622464126665,
#  5.529271600154953,
#  5.389194229415914,
#  5.4068993993993795,
#  5.470350194552501,
#  5.291917808219179,
#  5.444045290787414,
#  5.571974486966127,
#  5.453398260869513,
#  5.411169590643236,
#  5.406216375997577,
#  5.397945205479454,
#  5.451735947238327,
#  5.54126416739318,
#  5.410853540252163,
#  5.465056472632496,
#  5.512528409090909,
#  5.443552158273357,
#  5.29987508796623,
#  5.575493562231723,
#  5.303140168400142,
#  5.440507246376765,
#  5.464334565619186,
#  5.556300251256249,
#  5.436537879462436,
#  5.43869883934023,
#  5.445366434591424,
#  5.371116751269011,
#  5.415151733064859,
#  5.402253458277507,
#  5.566179326099341,
#  5.433901265371601,
#  5.347444331983758,
#  5.325638207945865,
#  5.401266532167606,
#  5.281621970087624,
#  5.427582733812955,
#  5.389527027026985,
#  5.494579273693522,
#  5.419370021723372,
#  5.4972602739726035,
#  5.29263236088604,
#  5.2946753246753255,
# ...

# %%
mean_value_sentiment = sum(cleaned_merge_list)/len(cleaned_merge_list)

# %%
mean_value_sentiment
# Out:
# 5.386581906264979

# %%
qqq = np.array(cleaned_merge_list)

  
              
print(np.percentile(qqq, 10))

print(np.percentile(qqq, 90))
# Out:
# 5.299709885544789
# 5.475068933732751

# %%
plt.hist(qqq)
plt.style.use('ggplot')
plt.hist(qqq,label = 'mean:5.4 10th-percentile:5.3 90th-percentile:5.488')
plt.legend()
plt.show()

# %% [markdown]
# # Good or Bad

# %%
goodorbad = pd.read_csv('D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/goodorbad.csv')

# %%
goodorbad.head()
# Out:
#    Unnamed: 0  CharacterName                 WikiLink universe  woman  man  \
# 0           0    Abomination  Abomination (character)   Marvel      0    1
# 1           1  Absorbing Man            Absorbing Man   Marvel      0    1
# 2           2         Achebe          Achebe (comics)   Marvel      0    0
# 3           3          Agent           Agent (comics)   Marvel      0    1
# 4           4        Agent X  Agent X (Marvel Comics)   Marvel      0    1
#
#    good  bad
# 0     0    1
# 1     0    1
# 2     0    0
# 3     1    0
# 4     1    0

# %%
goodorbad = goodorbad.drop(goodorbad.columns[[0]], axis = 1)

# %%
goodorbad
# Out:
#       CharacterName                                           WikiLink  \
# 0       Abomination                            Abomination (character)
# 1     Absorbing Man                                      Absorbing Man
# 2            Achebe                                    Achebe (comics)
# 3             Agent                                     Agent (comics)
# 4           Agent X                            Agent X (Marvel Comics)
# ...             ...                                                ...
# 2298            Xov                            Xov (Action Comics 242)
# 2299             XS                                        XS (comics)
# 2300            4-D  International Ultramarine Corps#Founding membe...
# 2301         500Z-Q                          Hero Hotline#Support crew
# 2302           #711                               711 (Quality Comics)
#
#      universe  woman  man  good  bad
# 0      Marvel      0    1     0    1
# 1      Marvel      0    1     0    1
# ...

# %%
goodorbad.replace(" ","_")
# Out:
#       CharacterName                                           WikiLink  \
# 0       Abomination                            Abomination (character)
# 1     Absorbing Man                                      Absorbing Man
# 2            Achebe                                    Achebe (comics)
# 3             Agent                                     Agent (comics)
# 4           Agent X                            Agent X (Marvel Comics)
# ...             ...                                                ...
# 2298            Xov                            Xov (Action Comics 242)
# 2299             XS                                        XS (comics)
# 2300            4-D  International Ultramarine Corps#Founding membe...
# 2301         500Z-Q                          Hero Hotline#Support crew
# 2302           #711                               711 (Quality Comics)
#
#      universe  woman  man  good  bad
# 0      Marvel      0    1     0    1
# 1      Marvel      0    1     0    1
# ...

# %%
goodorbad.loc[goodorbad['good'] == 1]
# Out:
#        CharacterName                              WikiLink universe  woman  \
# 3              Agent                        Agent (comics)   Marvel      0
# 4            Agent X               Agent X (Marvel Comics)   Marvel      0
# 10    American Eagle        American Eagle (Marvel Comics)   Marvel      0
# 12         Anarchist                              X-Statix   Marvel      0
# 15             Angel               Angel (Thomas Halloway)   Marvel      0
# ...              ...                                   ...      ...    ...
# 2245            Vibe                         Vibe (comics)       DC      0
# 2251   Viking Prince                         Viking Prince       DC      0
# 2264           Vixen                        Vixen (comics)       DC      1
# 2295     Xiuhtecutli  Cadre (comics)#Cadre of the Immortal       DC      0
# 2297           Xombi                                 Xombi       DC      0
#
#       man  good  bad
# 3       1     1    0
# 4       1     1    0
# ...

# %%
goodorbad.loc[goodorbad['bad'] == 1]
# Out:
#       CharacterName                 WikiLink universe  woman  man  good  bad
# 0       Abomination  Abomination (character)   Marvel      0    1     0    1
# 1     Absorbing Man            Absorbing Man   Marvel      0    1     0    1
# 6        Air-Walker               Air-Walker   Marvel      0    1     0    1
# 17           Angela          Angela (comics)   Marvel      1    0     0    1
# 21        Annihilus                Annihilus   Marvel      0    1     0    1
# ...             ...                      ...      ...    ...  ...   ...  ...
# 2211     Tony Zucco               Tony Zucco       DC      0    1     0    1
# 2223  Vandal Savage            Vandal Savage       DC      0    1     0    1
# 2243  Veronica Cale            Veronica Cale       DC      1    0     0    1
# 2267        Volcana                  Volcana       DC      1    0     0    1
# 2280        Vulture            Terrible Trio       DC      0    1     0    1
#
# [404 rows x 7 columns]

# %%
goodorbad.loc[goodorbad['bad'] == 1]['WikiLink']
# Out:
# 0       Abomination (character)
# 1                 Absorbing Man
# 6                    Air-Walker
# 17              Angela (comics)
# 21                    Annihilus
#                  ...
# 2211                 Tony Zucco
# 2223              Vandal Savage
# 2243              Veronica Cale
# 2267                    Volcana
# 2280              Terrible Trio
# Name: WikiLink, Length: 404, dtype: object

# %%
goodorbad.loc[goodorbad['good'] == 1]['WikiLink']
# Out:
# 3                             Agent (comics)
# 4                    Agent X (Marvel Comics)
# 10            American Eagle (Marvel Comics)
# 12                                  X-Statix
# 15                   Angel (Thomas Halloway)
#                         ...
# 2245                           Vibe (comics)
# 2251                           Viking Prince
# 2264                          Vixen (comics)
# 2295    Cadre (comics)#Cadre of the Immortal
# 2297                                   Xombi
# Name: WikiLink, Length: 410, dtype: object

# %%
goodlist = goodorbad.loc[goodorbad['good'] == 1]['WikiLink']

# %%
badlist = goodorbad.loc[goodorbad['bad'] == 1]['WikiLink']

# %%
sentidictmarvel = {}
for i in wenjianjia2:
    sentidictmarvel[i] = calculate_sentiment_value(i)

# %%
sentidictmarvel
# Out:
# {'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/marvel\\3-D_Man.txt': 5.488878069432629,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/marvel\\Abigail_Brand.txt': 5.335026002971731,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/marvel\\Abner_Jenkin.txt': 5.331379210220604,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/marvel\\Abomination_(character).txt': 5.383867768594975,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/marvel\\Abraham_Corneliu.txt': 5.307005899704988,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/marvel\\Abraham_Whistler.txt': 5.3297792408985005,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/marvel\\Absorbing_Man.txt': 5.425455588707747,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/marvel\\Achebe_(comics).txt': 5.397945205479454,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/marvel\\Adam_Warlock.txt': 5.460832514734795,
# ...

# %%
sentidictdc = {}
for i in wenjianjia:
    sentidictdc[i] = calculate_sentiment_value(i)

# %%
sentidictdc
# Out:
# {'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\711_(Quality_Comics).txt': None,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Abby_Holland.txt': 5.389032815198586,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Abin_Sur.txt': 5.285731064237726,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Abra_Kadabra_(character).txt': 5.40622464126665,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Ace_the_Bat-Hound.txt': 5.529271600154953,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Adam_Strang.txt': 5.389194229415914,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Agent_Liberty.txt': 5.4068993993993795,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Air_Wav.txt': 5.470350194552501,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Albert_Rothstein.txt': 5.291917808219179,
# ...

# %%
goodlist_cleaned = []
for i in goodlist:
    j = i.replace(' ','_')
    goodlist_cleaned.append(j)

# %%
goodlist_cleaned
# Out:
# ['Agent_(comics)',
#  'Agent_X_(Marvel_Comics)',
#  'American_Eagle_(Marvel_Comics)',
#  'X-Statix',
#  'Angel_(Thomas_Halloway)',
#  'Angel_Dust_(comics)',
#  'Ant-Man',
#  'Anti-Venom_(symbiote)',
#  'Ares_(Marvel_Comics)',
#  'Armor_(comics)',
#  'Arsenal_(Marvel_Comics)',
#  'Gertrude_Yorkes',
#  'Vance_Astro',
#  'Aurora_(comics)',
#  'Breeze_Barton',
#  'Battlestar_(comics)',
#  'Beast_(comics)',
#  'Beta_Ray_Bill',
#  'Beyonder',
#  'Bird-Brain_(Marvel_Comics)',
#  'Bishop_(Marvel_Comics)',
#  'Black_Bolt',
#  'Black_Cat_(Marvel_Comics)',
#  'Black_Marvel',
#  "Black_Panther_(character)|T'Challa_(Marvel_Cinematic_Universe)",
#  'Black_Widow_(Marvel_Comics)',
#  'Blade_(character)',
#  'Thor_(Marvel_Comics)',
#  'Blazing_Skull',
#  'Bling!',
#  'Blink_(comics)',
#  'Bloodhawk',
#  'Chris_Bradley',
#  'Tabitha_Smith',
#  'G._W._Bridge',
#  'Brimstone_Love',
#  'Brother_Voodoo',
#  'Molly_Hayes',
#  'Bug_(comics)',
#  'Cable_(comics)',
#  'Luke_Cage',
#  'Cannonball_(comics)',
# ...

# %%
badlist_cleaned = []
for i in badlist:
    j = i.replace(' ','_')
    badlist_cleaned.append(j)

# %%
badlist_cleaned
# Out:
# ['Abomination_(character)',
#  'Absorbing_Man',
#  'Air-Walker',
#  'Angela_(comics)',
#  'Annihilus',
#  'Apocalypse_(comics)',
#  'Arcade_(Marvel_Comics)',
#  'Arclight_(comics)',
#  'Aries_(comics)',
#  'Armadillo_(comics)',
#  'Asbestos_Man',
#  'Erik_Josten',
#  'Azazel_(Marvel_Comics)',
#  'Brian_Banner',
#  'Baron_Blood',
#  'Baron_Brimstone',
#  'Baron_Zemo',
#  'Barracuda_(comics)',
#  'Bastion_(comics)',
#  'Batroc_the_Leaper',
#  'Bedlam_(comics)',
#  'Beetle_(comics)',
#  'Belasco_(Marvel_Comics)',
#  'Bengal_(comics)',
#  'Big_Man_(comics)',
#  'Bird-Man',
#  'Black_Mamba_(comics)',
#  'Black_Tarantula',
#  'Black_Tom_Cassidy',
#  'Blackout_(Marcus_Daniels)',
#  'Blackwing_(character)',
#  'Siena_Blaze',
#  'Blizzard_(Marvel_Comics)',
#  'Blob_(comics)',
#  'Bloodaxe_(comics)',
#  'Bloodstrike_(Marvel_Comics)',
#  'Box_(comics)',
#  'Brute_(Reed_Richards)',
#  'Bullseye_(comics)',
#  'Bushman_(comics)',
#  'Bushmaster_(Marvel_Comics)',
#  'Bushwacker_(comics)',
# ...

# %%
merge_dict = {**sentidictdc, **sentidictmarvel}

# %%
merge_dict
# Out:
# {'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\711_(Quality_Comics).txt': None,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Abby_Holland.txt': 5.389032815198586,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Abin_Sur.txt': 5.285731064237726,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Abra_Kadabra_(character).txt': 5.40622464126665,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Ace_the_Bat-Hound.txt': 5.529271600154953,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Adam_Strang.txt': 5.389194229415914,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Agent_Liberty.txt': 5.4068993993993795,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Air_Wav.txt': 5.470350194552501,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Albert_Rothstein.txt': 5.291917808219179,
# ...

# %%
for i in merge_dict:                  # Delete None elements
    if merge_dict[i] == None:
        del merge_dict[i]

# %%
merge_dict
# Out:
# {'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Abby_Holland.txt': 5.389032815198586,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Abin_Sur.txt': 5.285731064237726,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Abra_Kadabra_(character).txt': 5.40622464126665,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Ace_the_Bat-Hound.txt': 5.529271600154953,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Adam_Strang.txt': 5.389194229415914,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Agent_Liberty.txt': 5.4068993993993795,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Air_Wav.txt': 5.470350194552501,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Albert_Rothstein.txt': 5.291917808219179,
#  'D:/LEARNING/BA/2022.9-2022.12/Social graph/ASSIGNMENT 2/dc\\Alura_(DC_Comics).txt': 5.444045290787414,
# ...

# %%
final_merge = {}
for i in merge_dict:
    final_merge[i[i.index("\\")+1:len(i)-4]] = merge_dict[i]

# %%
#ceshi.index("\\")
# Out:
# 58

# %%
#ceshi[58+1:len(ceshi)-4]
# Out:
# 'Abby_Holland'

# %%
final_merge
# Out:
# {'Abby_Holland': 5.389032815198586,
#  'Abin_Sur': 5.285731064237726,
#  'Abra_Kadabra_(character)': 5.40622464126665,
#  'Ace_the_Bat-Hound': 5.529271600154953,
#  'Adam_Strang': 5.389194229415914,
#  'Agent_Liberty': 5.4068993993993795,
#  'Air_Wav': 5.470350194552501,
#  'Albert_Rothstein': 5.291917808219179,
#  'Alura_(DC_Comics)': 5.444045290787414,
#  'Amazing-Man_(DC_Comics)': 5.571974486966127,
#  'Amazo': 5.453398260869513,
#  'Ambush_Bug': 5.411169590643236,
#  'Amethyst,_Princess_of_Gemworld': 5.406216375997577,
#  'Amygdala_(comics)': 5.397945205479454,
#  'Anarky': 5.451735947238327,
#  'Angel_and_the_Ap': 5.54126416739318,
#  'Animal-Vegetable-Mineral_Man': 5.410853540252163,
#  'Animal_Man': 5.465056472632496,
#  'Anna_Fortun': 5.512528409090909,
#  'Anthro_(comics)': 5.443552158273357,
#  'Anti-Monitor': 5.29987508796623,
#  'Antiope_(character)': 5.575493562231723,
#  'Anton_Arcan': 5.303140168400142,
#  'Apache_Chief': 5.440507246376765,
# ...

# %%
# Calculate good guys

goodscore = []
for i in goodlist_cleaned:
    if i in final_merge:
        goodscore.append(final_merge[i])
    else:
        continue

# %%
goodscore
# Out:
# [5.3618174962292535,
#  5.365564614757397,
#  5.453112840466878,
#  5.401376994122549,
#  5.453467804499596,
#  5.476338028169017,
#  5.529055393585975,
#  5.164415584415584,
#  5.340216703189632,
#  5.417972972972975,
#  5.329106203995777,
#  5.398348151614375,
#  5.3891165755919195,
#  5.462517552657957,
#  5.386623376623378,
#  5.3076623376623395,
#  5.3290998542273496,
#  5.578044444444458,
#  5.31314345991553,
#  5.504427793680086,
#  5.369441305712485,
#  5.356865441459886,
#  5.471292750230065,
#  5.329078947368422,
#  5.394415584415585,
#  5.317107208872429,
#  5.343904347826077,
#  5.331448500348685,
#  5.389467116357449,
#  5.3569658119658,
#  5.410519480519482,
#  5.414383561643837,
#  5.380253999999869,
#  5.423272019808936,
#  5.361837569745778,
#  5.491977077363908,
#  5.346440677966102,
#  5.398051948051949,
#  5.308399513776364,
#  5.3026326129665655,
#  5.4695327102803475,
#  5.319382716049384,
#  5.436987767584099,
#  5.3995886075948984,
#  5.397945205479454,
# ...

# %%
mean_value_goodguy = sum(goodscore)/len(goodscore)
goodguy = np.array(goodscore)      
print(np.percentile(goodguy, 10))

print(np.percentile(goodguy, 90))
print(mean_value_goodguy)
# Out:
# 5.32724129272812
# 5.4965353607133896
# 5.4117061888908875

# %%
plt.hist(goodguy)
plt.style.use('ggplot')
plt.hist(goodguy,label = 'mean:5.4 10th-percentile:5.3 90th-percentile:5.5')
plt.legend()
plt.show()

# %%
# Calculate bad guys

badscore = []
for i in badlist_cleaned:
    if i in final_merge:
        badscore.append(final_merge[i])
    else:
        continue

# %%
mean_value_badguy = sum(badscore)/len(badscore)
badguy = np.array(badscore)      
print(np.percentile(badguy, 10))

print(np.percentile(badguy, 90))
print(mean_value_badguy)
# Out:
# 5.292494246038948
# 5.440049805293379
# 5.366968116088012

# %%
plt.hist(badguy)
plt.style.use('ggplot')
plt.hist(badguy,label = 'mean:5.367 10th-percentile:5.3 90th-percentile:5.4')
plt.legend()
plt.show()

# %% [markdown]
# # Permutation test

# %% [markdown]
# H1: Good characters have a higher averge value for sentiment than a similarly sized set of randomly selected characters.
#
# H2: Bad characters have a lower average value for sentiment than a similarly sized set of randomly selected characters.

# %%
# First we test H1
# We suppose the null test is H0: Good characters do not have a higher averge value for sentiment than a similarly sized set of randomly selected characters.
# It means that if the null test H0 is right, the two groups——good and bad, they are from the same distribution.

#We calculate the statistics:

Statistics = mean_value_goodguy - mean_value_badguy
print('statistics = ',Statistics)

# We can get the P-value through the position of the Statistics in the permutation distribution


# Concatenate the data set:

data = np.concatenate((goodscore,badscore))

# Permute the data:

Permuted_data = np.random.permutation(data)

# Split the permuted data into 2 sample groups:

sample1 = Permuted_data[:len(goodscore)]
sample2 = Permuted_data[len(goodscore):]

difference_of_the_sample = np.mean(sample1) - np.mean(sample2)
print(difference_of_the_sample)
# Out:
# statistics =  0.04473807280287545
# 0.013291792452795548

# %%
results = []
data = np.concatenate((goodscore,badscore))
for i in range(1000):
    Permuted_data = np.random.permutation(data)
    sample1 = Permuted_data[:len(goodscore)]
    sample2 = Permuted_data[len(goodscore):]
    difference_of_the_sample = np.mean(sample1) - np.mean(sample2)
    results.append(difference_of_the_sample)

# %%
results
# Out:
# [-0.0048836574222326234,
#  0.009589847072727586,
#  0.006917699733617333,
#  -0.003629965460637763,
#  -0.003363170072540278,
#  -0.002339514244246388,
#  -0.0029863994978311936,
#  0.0046681279539750875,
#  -0.008705246636502295,
#  -0.007673258119533344,
#  -0.005914946829716605,
#  -0.013238583060814157,
#  0.0028506490038164856,
#  -0.003496298932512687,
#  -0.006028533972530781,
#  -0.001482981293611907,
#  0.0006005123287620151,
#  0.0012355750748547223,
#  0.00280260831489354,
#  0.005597445744685459,
#  0.0026803513589941375,
#  -0.0074319670028435425,
#  0.004879241399452283,
#  0.00235479365695479,
#  0.007647913958236607,
#  -0.0007906825439185639,
#  -0.0008918907541586307,
#  0.0011568553690119998,
#  0.008714412370956381,
#  -0.002055143167981832,
#  -0.0005770658160066944,
#  0.004389914291061281,
#  -3.0242037776240238e-05,
#  0.0014081837497830207,
#  0.004265099618867119,
#  0.004129070052483641,
#  -0.011812389700400772,
#  -0.0009946152008986076,
# ...

# %%
count = 0
for i in results:
    if i > Statistics:
        count = count + 1
print(count)    # 0???????? P value = 0
# Out:
# 0

# %%
# It means that the H0 is almost impossible, so we must refuse the H0
# So, we can get to the conclusion: Good characters Do have a higher averge value for sentiment than a similarly sized set of randomly selected characters.

# %%
# Then we test H2
# We suppose  H0: Bad characters do not have a lower average value for sentiment than a similarly sized set of randomly selected characters.

#We calculate the statistics:

Statistics2 = mean_value_badguy - mean_value_goodguy
print('statistics2 = ',Statistics2)

# We can get the P-value through the position of the Statistics in the permutation distribution


# Concatenate the data set:

data2 = np.concatenate((badscore,goodscore))

# Permute the data:

Permuted_data2 = np.random.permutation(data2)

# Split the permuted data into 2 sample groups:

sample1_2 = Permuted_data[:len(badscore)]
sample2_2 = Permuted_data[len(badscore):]

difference_of_the_sample2 = np.mean(sample1_2) - np.mean(sample2_2)
print(difference_of_the_sample2)
# Out:
# statistics2 =  -0.04473807280287545
# -0.0012025473090115923

# %%
results2 = []
data2 = np.concatenate((badscore,goodscore))
for i in range(1000):
    Permuted_data2 = np.random.permutation(data2)
    sample1_2 = Permuted_data[:len(badscore)]
    sample2_2 = Permuted_data[len(badscore):]
    difference_of_the_sample2 = np.mean(sample1_2) - np.mean(sample2_2)
    results2.append(difference_of_the_sample2)

# %%
count2 = 0
for i in results2:
    if i < Statistics2:
        count2 = count2 + 1
print(count2)    # 0???????? P value = 0
# Out:
# 0

# %%
# It means that the H0 is almost impossible, so we must refuse the H0
# So, we can get to the conclusion: Bad characters have a lower average value for sentiment than a similarly sized set of randomly selected characters.
